# %% [markdown]
# **Gold Scraper**
#
# This is a notebook showing how to webscrape gold price from website. The scraped website comes from ANTAM (logammulia.com/id) and contains selling and buyback price of gold
#
# This tutorial utilizes selenium to scrape the element of the website and store it into certain location

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/Google Colab/Gold Price Scrapper/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Google Colab/Gold Price Scrapper

# %%
pip install selenium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 30.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.7/475.7 kB 39.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.3.1+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# ...

# %%
pip install chromium chromium-driver
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement chromium-driver (from versions: none)
# ERROR: No matching distribution found for chromium-driver

# %%
import pandas as pd
from gold_price_source import *

# %%
price_lotus()
# Out:
#     Size (gr)      Price       Source        date    Buyback
# 0         0.1     189000  Lotus Archi  2024-07-23     125400
# 1         0.2     376000  Lotus Archi  2024-07-23     250800
# 2         0.5     724000  Lotus Archi  2024-07-23     627000
# 4         1.0    1387000  Lotus Archi  2024-07-23    1254000
# 5         2.0    2729000  Lotus Archi  2024-07-23    2508000
# 6         5.0    6792000  Lotus Archi  2024-07-23    6270000
# 7        10.0   13524000  Lotus Archi  2024-07-23   12540000
# 8        25.0   33710000  Lotus Archi  2024-07-23   31350000
# 9        50.0   67320000  Lotus Archi  2024-07-23   62700000
# 10      100.0  134541000  Lotus Archi  2024-07-23  125400000

# %%
price_antam()
# Out:
#     Size (gr)       Price Source        date     Buyback
# 0         0.5      752000  Antam  2024-07-23      627000
# 1         1.0     1404000  Antam  2024-07-23     1254000
# 2         2.0     2748000  Antam  2024-07-23     2508000
# 3         3.0     4097000  Antam  2024-07-23     3762000
# 4         5.0     6795000  Antam  2024-07-23     6270000
# 5        10.0    13535000  Antam  2024-07-23    12540000
# 6        25.0    33712000  Antam  2024-07-23    31350000
# 7        50.0    67345000  Antam  2024-07-23    62700000
# 8       100.0   134612000  Antam  2024-07-23   125400000
# 9       250.0   336265000  Antam  2024-07-23   313500000
# 10      500.0   672320000  Antam  2024-07-23   627000000
# 11     1000.0  1344600000  Antam  2024-07-23  1254000000
